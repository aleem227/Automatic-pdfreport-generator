# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/pdf_reports/
# Out:
# /content/gdrive/MyDrive/pdf_reports

# %%
# %cd pdf_reports
# Out:
# /content/gdrive/MyDrive/pdf_reports/pdf_reports

# %%
# !pip install pdf_reports
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.4/118.4 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.6/267.6 kB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.9/848.9 kB 51.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 89.4 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# binary_report_generator.py	    MultiClassClassification-class.pdf
# build				    multicolor_bar_plot.py
# calibration_curve.py		    pdf_reports
# Classification-class.pdf	    pdf_reports.egg-info
# Classification-new.pdf		    pdp_plot.py
# Classification.pdf		    performance_table.py
# classification_report_generator.py  precision_plot.py
# confusion_matrix_plot.py	    __pycache__
# data_table.py			    pypi-readme.rst
# dist				    README.rst
# docs				    Regression-class.pdf
# examples			    Regression-new.pdf
# ez_setup.py			    Regression.pdf
# feature_importance.py		    report_generator.py
# font_style.py			    roc_curve.py
# json_files			    screenshot.png
# LICENCE.txt			    setup.py
# lift_chart.py			    tests
# MANIFEST.in

# %%
from binary_report_generator import ReportGenerator

# Create an instance of ReportGenerator
report_generator = ReportGenerator()

# Generate PDF report
report_generator.generate_pdf_report(
    r"./examples/working_example/page3.html",
    title="Binary Classification in Machine Learning",
    author="Ali Zeeshan"
)
# Out:
# Available fonts:
# 1. Times New Roman
# 2. Arial
# 3. Garamond
# 4. Helvetica
# 5. Courier New
# Enter the number of the font you want to choose for document (1/2/3/4/5): 1
# Available color groups for Multicolor Bar Plot:
# 1. Group1 includes these colors: red, blue, yellow, green
# 2. Group2 includes these colors: blue, green, red, black
# Select a color group by entering the group number: 1
# Select a color group for Performance Plot (1 for group1, 2 for group2): 1
# Select a bar color for Feature Importance Graph:
# 1: blue
# 2: green
# 3: red
# Enter the number corresponding to your color choice: 2
# WARNING:weasyprint:Invalid or unsupported selector '[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner', (<IdentToken -moz-focus-inner>, 'Expected a supported pseudo-element, got -moz-focus-inner')
# WARNING:weasyprint:Ignored `outline:1px dotted ButtonText` at 19:1828, invalid value.
# ...
